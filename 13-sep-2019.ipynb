# %% [markdown]
# ### VISULISATION OF DATA USING matplotlib

# %%
# %matplotlib notebook
import matplotlib as mp1
import matplotlib.pyplot as plt

# %%
plt.plot(2,3,'v')
# Out:
# <img src="data:image/png;base64,..." width="639.9999886971934">

# %%
plt.plot(2,3,'or')

# %% [markdown]
# #### [reference for different points]
# https://matplotlib.org/3.1.0/api/markers_api.html

# %%
plt.title("Line equation")
# Out:
# Text(0.5, 1.0, 'Line equation')

# %%
plt.xlabel("users")
# Out:
# Text(0.5, 31.65500089459949, 'users')

# %%
plt.ylabel("users")
# Out:
# Text(45.87500154309803, 0.5, 'users')

# %%
plt.ylabel("ages")
# Out:
# Text(45.87500154309803, 0.5, 'ages')

# %%
x=[1,2,3,4,5,6]
y=[1,4,9,16,25,36]

# %%
plt.figure()
plt.plot(x,y,"o-")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999886971934">
